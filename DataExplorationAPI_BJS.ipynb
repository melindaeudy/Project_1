# %% [markdown]
# # DataExplorationAPI_BJS - National Crime Victimization Survey (NCVS)
# ----
#
# # Dataset: Bureau of Justice Statistics (BJS)

# %%
# Dependencies and Setup

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import scipy.stats as st
from datetime import date
import json
import xmltodict

# %%
# User functions to be used

def append_dict_to_df(current_dict, current_index, current_df):
    single_df = pd.DataFrame(current_dict, index=[current_index])
    if current_df.empty:
        current_df = single_df.copy()
    else:
        current_df = current_df.append(single_df)        
    current_index += 1
    return current_df,current_index

def get_incidents(endpoint, field, format_type):
    # Build query URL
    query_url = f"{base_url}{endpoint}?format={format_type}"
    # Call API and get response
    response = requests.get(query_url)
    current_json = response.json()
    return pd.DataFrame(current_json[field])

def get_fields(endpoint):
    # Build query URL
    query_url = f"{base_url}{endpoint}" # XML only
    # Call API and get response
    response = requests.get(query_url)
    fields_ord_dict = xmltodict.parse(response.content) # Ordered dictionary
    fields_idx = 0
    values_idx = 0
    fields_df = pd.DataFrame()
    values_df = pd.DataFrame()
    for key_level1 in fields_ord_dict: # 'bjsDataSetFields'
        for key_level2 in fields_ord_dict[key_level1]: # 'fields'
            for field in fields_ord_dict[key_level1][key_level2]:
                field_id = field['id']
                fields_dict = {
                    "field_id": field_id,
                    "field_name": field['name'],
                    "field_description": field['description']
                }
                fields_df,fields_idx = append_dict_to_df(fields_dict, fields_idx, fields_df)
                values = field['values']
                if type(values) is list:
                    for idx in range(len(values)):
                        value_ord_dict = values[idx]
                        values_dict = {
                            "field_id": field_id,
                            "value_name": value_ord_dict['name'],
                            "value_description": value_ord_dict['description']
                        }
                        values_df,values_idx = append_dict_to_df(values_dict, values_idx, values_df)
                else:
                    value_ord_dict = values
                    values_dict = {
                        "field_id": field_id,
                        "value_name": value_ord_dict['name'],
                        "value_description": value_ord_dict['description']
                    }
                    values_df,values_idx = append_dict_to_df(values_dict, values_idx, values_df)               
    return pd.merge(fields_df,values_df, on="field_id")

def get_desc(df, input_field1, field1_value, input_field2, field2_value, output_field):
    value = df.loc[(df[input_field1] == field1_value) & (df[input_field2] == field2_value), output_field]
    try:
        return value.values[0]
    except IndexError:
        return value.values

def translate_df(df, field_df, offset):
    new_df = df.copy()
    input_field1 = 'field_id' # does not change
    input_field2 = 'value_name' # does not change
    output_field = 'value_description'  # does not change
    for index, row in new_df.iterrows():
        for col in range(len(new_df.columns)-offset):
            field1_value = new_df.columns[col+offset]
            field2_value = row[col+offset]
            value_description = get_desc(field_df, input_field1, field1_value, input_field2, field2_value, output_field)
            row[col+offset] = value_description
    return new_df

def Mbox(title, text, style):
    return ctypes.windll.user32.MessageBoxW(0, text, title, style)

def build_scatter_plot(df, colx, coly, title, xlabel, ylabel, file):
    # Build a scatter plot
    plt.scatter(df[colx], df[coly], marker="o")
    # Incorporate the other graph properties
    plt.title(title)
    plt.ylabel(ylabel)
    plt.xlabel(xlabel)
    plt.grid(True)
    # Save the figure
    plt.savefig(file)
    # Show plot
    plt.show()
    
def build_linear_regression(df, colx, coly, title, xlabel, ylabel, file, le_x, le_y, r_x, r_y):
    # Perform a linear regression on coly vs. colx
    x_values = df[colx]
    y_values = df[coly]
    # Calculate the line equation using linear regression function
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    # Plot original data using Scatter type
    plt.scatter(x_values,y_values, label='original data')
    # Plot fitted line using Line type
    plt.plot(x_values,regress_values,"r-", label='fitted line')
    # Add line equation to plot
    plt.annotate(line_eq,(le_x,le_y),fontsize=15,color="red")
    # Set title, xlabel, ylabel and legend
    plt.title(title)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.legend()
    # Show r-squared value
    r2_latex = r'$r^2 = $'
    r2_value = f'{r2_latex}{round(rvalue**2,4)}'
    plt.annotate(r2_value,(r_x,r_y),fontsize=15,color="green")
    print(f"The r-value is: {rvalue}")
    # Save the figure
    plt.savefig(file)
    # Show plot
    plt.show()

# %%
# General Config information

base_url = "https://api.bjs.ojp.gov"
format_type = "json"
personal_field = 'personalData'
household_field = 'householdData'
year = '2019'

# %% [markdown]
# ## List of available NCVS DATASETS and their data types.

# %%
# ENDPOINT
endpoint = "/bjs/ncvs/v2"

# Build query URL
query_url = f"{base_url}{endpoint}" # XML only

# Call API and get response
response = requests.get(query_url)

# General DataFrame
datasets_ord_dict = xmltodict.parse(response.content)
general_dict = {
    "title": datasets_ord_dict['bjsDataSet']['title'],
    "basePath": datasets_ord_dict['bjsDataSet']['basePath'],
    "description": datasets_ord_dict['bjsDataSet']['description']
}
general_df = pd.DataFrame(general_dict, index=[0])

# Resources DataFrame
datasets_idx = 0
datasets_df = pd.DataFrame()
dataset_formats_idx = 0
dataset_formats_df = pd.DataFrame()
for idx in range(len(datasets_ord_dict['bjsDataSet']['resources'])):
    current_dict = datasets_ord_dict['bjsDataSet']['resources'][idx]
    datasets_dict = {
        "title": current_dict["title"],
        "description": current_dict["description"]
    }
    datasets_df,datasets__idx = append_dict_to_df(datasets_dict, datasets_idx, datasets_df)
    for key in current_dict:
        formats_dict = current_dict["formats"]
        for cur_link in range(len(formats_dict['links'])):
            dataset_formats_dict = {
                "format": formats_dict['format'],
                "link": formats_dict['links'][cur_link]['link']
            }
            dataset_formats_df,dataset_formats_idx = append_dict_to_df(dataset_formats_dict, 
                                                                       dataset_formats_idx, 
                                                                       dataset_formats_df)
general_df
# Out:
#                                             title                   basePath  \
# 0  National Crime Victimization Survey (NCVS) API  /developer/ncvs/index.cfm
#
#                                          description
# 0  The National Crime Victimization Survey (NCVS)...

# %%
datasets_df
# Out:
#                      title                                        description
# 0   Personal Victimization  Personal victimization includes all violent vi...
# 0  Household Victimization  Household victimization includes all property ...

# %%
dataset_formats_df.head()
# Out:
#   format                                               link
# 0    CSV  /developer/ncvs/data/csv/NCVS_PERSONAL_1993-20...
# 1    CSV  /developer/ncvs/data/csv/NCVS_PERSONAL_2010-20...
# 2    CSV  /developer/ncvs/data/csv/NCVS_PERSONAL_2015-20...
# 3    CSV  /developer/ncvs/data/csv/NCVS_PERSONAL_1993-20...
# 4    CSV  /developer/ncvs/data/csv/NCVS_PERSONAL_2010-20...

# %% [markdown]
# # PERSONAL victimization datasets

# %% [markdown]
# ## Description of the FIELDS or columns used in the PERSONAL victimization datasets

# %%
# ENDPOINT
endpoint = "/bjs/ncvs/v2/personal/fields/"

bjsPersonalDataSetFields_df = get_fields(endpoint)
bjsPersonalDataSetFields_df
# Out:
#    field_id       field_name  \
# 0      ager              Age
# 1      ager              Age
# 2      ager              Age
# 3      ager              Age
# 4      ager              Age
# ..      ...              ...
# 84  weapcat  Weapon category
# 85  weapcat  Weapon category
# 86   weight           Weight
# 87   weight           Weight
# 88     year             Year
#
#                                     field_description     value_name  \
# 0   The respondent's age on the last day of the mo...              1
# 1   The respondent's age on the last day of the mo...              2
# 2   The respondent's age on the last day of the mo...              3
# 3   The respondent's age on the last day of the mo...              4
# 4   The respondent's age on the last day of the mo...              5
# ..                                                ...            ...
# 84  Types of weapons present during  the victimiza...              4
# 85  Types of weapons present during  the victimiza...              5
# 86                                  Weight definition     Population
# 87                                  Weight definition  Victimization
# 88                              Year of victimization      1993-2019
#
#                                     value_description
# 0                                            12 to 14
# 1                                            15 to 17
# 2                                            18 to 20
# 3                                            21 to 24
# 4                                            25 to 34
# ..                                                ...
# 84                                Type weapon unknown
# 85                 Do not know if offender had weapon
# 86  This weight is attached to the person populati...
# 87  The weight used to calculate an estimate of vi...
# 88                                        Valid years
#
# [89 rows x 5 columns]

# %% [markdown]
# ##  PERSONAL victimization COUNTS of incidents reported to the NCVS by year 2019

# %%
# ENDPOINT
endpoint = f"/bjs/ncvs/v2/personal/{year}"

personal_counts_df = get_incidents(endpoint, personal_field, format_type)
personal_counts_df = translate_df(personal_counts_df, bjsPersonalDataSetFields_df, 2)
personal_counts_df
# Out:
#          weight  year         ager                            direl  \
# 0     901.72876  2019     25 to 34                         Stranger
# 1     1135.6383  2019     25 to 34  Well-known/casual acquaintances
# 2     782.97064  2019     50 to 64  Well-known/casual acquaintances
# 3      4110.831  2019     50 to 64  Well-known/casual acquaintances
# 4      4110.831  2019     50 to 64  Well-known/casual acquaintances
# ...         ...   ...          ...                              ...
# 2237  1419.9874  2019     50 to 64                         Stranger
# 2238   3103.832  2019     50 to 64                         Stranger
# 2239  1581.4188  2019     25 to 34                         Stranger
# 2240  1556.2935  2019  65 or older                  Other relatives
# 2241   4157.733  2019     35 to 49                         Stranger
#
#                 ethnic1R  gender             hincome      hispanic  \
# 0     Non-Hispanic white  Female    Less than $7,500  Non-Hispanic
# 1               Hispanic  Female  $15,000 to $24,999      Hispanic
# 2     Non-Hispanic white    Male  $50,000 to $74,999  Non-Hispanic
# 3               Hispanic    Male             Unknown      Hispanic
# 4               Hispanic    Male             Unknown      Hispanic
# ...                  ...     ...                 ...           ...
# 2237  Non-Hispanic white    Male     $75,000 or more  Non-Hispanic
# 2238  Non-Hispanic white    Male  $35,000 to $49,999  Non-Hispanic
# 2239  Non-Hispanic other  Female    Less than $7,500  Non-Hispanic
# 2240  Non-Hispanic white    Male  $50,000 to $74,999  Non-Hispanic
# 2241            Hispanic    Male     $75,000 or more      Hispanic
#
#            injury                                          locationr  ...  \
# 0     Not injured  Commercial place, parking lot, or other public...  ...
# 1     Not injured                                     Other location  ...
# 2     Not injured                           At or near victim's home  ...
# 3     Not injured  Commercial place, parking lot, or other public...  ...
# 4     Not injured  Commercial place, parking lot, or other public...  ...
# ...           ...                                                ...  ...
# 2237  Not injured  Commercial place, parking lot, or other public...  ...
# 2238  Not injured  Commercial place, parking lot, or other public...  ...
# 2239  Not injured                           At or near victim's home  ...
# 2240  Not injured  Commercial place, parking lot, or other public...  ...
# 2241      Injured                                     Other location  ...
#
#                    newoff                            notify  \
# 0          Simple assault  No, did not report to the police
# 1          Simple assault  No, did not report to the police
# 2          Simple assault       Yes, reported to the police
# 3          Simple assault  No, did not report to the police
# 4          Simple assault  No, did not report to the police
# ...                   ...                               ...
# 2237       Simple assault  No, did not report to the police
# 2238  Rape/sexual assault  No, did not report to the police
# 2239       Simple assault       Yes, reported to the police
# 2240       Simple assault       Yes, reported to the police
# 2241   Aggravated assault       Yes, reported to the police
#
#                  popsize race1R   region  \
# 0          Under 100,000  White  Midwest
# 1            Not a place  White  Midwest
# 2            Not a place  White  Midwest
# 3     500,000 to 999,999  White     West
# 4     500,000 to 999,999  White     West
# ...                  ...    ...      ...
# 2237         Not a place  White  Midwest
# 2238       Under 100,000  White    South
# 2239  100,000 to 249,999  Other    South
# 2240         Not a place  White    South
# 2241       Under 100,000  White    South
#
#                               seriousviolent  \
# 0                             Simple assault
# 1                             Simple assault
# 2                             Simple assault
# 3                             Simple assault
# 4                             Simple assault
# ...                                      ...
# 2237                          Simple assault
# 2238  Violent crime excluding simple assault
# 2239                          Simple assault
# 2240                          Simple assault
# 2241  Violent crime excluding simple assault
#
#                                               treatment  \
# 0                                           Not injured
# 1                                           Not injured
# 2                                           Not injured
# 3                                           Not injured
# 4                                           Not injured
# ...                                                 ...
# 2237                                        Not injured
# 2238                                        Not injured
# 2239                                        Not injured
# 2240                                        Not injured
# 2241  Treated at scene, home, medical office, or oth...
#
#                                             vicservices  \
# 0     No services received from victim service agencies
# 1     No services received from victim service agencies
# 2     No services received from victim service agencies
# 3     No services received from victim service agencies
# 4     No services received from victim service agencies
# ...                                                 ...
# 2237  No services received from victim service agencies
# 2238  No services received from victim service agencies
# 2239     Services received from victim service agencies
# 2240  No services received from victim service agencies
# 2241  No services received from victim service agencies
#
#                                  weapcat                              weapon
# 0                              No weapon    No, offender did not have weapon
# 1                              No weapon    No, offender did not have weapon
# 2                              No weapon    No, offender did not have weapon
# 3                              No weapon    No, offender did not have weapon
# 4                              No weapon    No, offender did not have weapon
# ...                                  ...                                 ...
# 2237                           No weapon    No, offender did not have weapon
# 2238                           No weapon    No, offender did not have weapon
# 2239                           No weapon    No, offender did not have weapon
# 2240  Do not know if offender had weapon  Do not know if offender had weapon
# 2241                   Other type weapon           Yes,  offender had weapon
#
# [2242 rows x 23 columns]

# %% [markdown]
# ## PERSONAL victimization POPULATION of incidents reported to the NCVS by year 2019

# %%
# ENDPOINT
endpoint = f"/bjs/ncvs/v2/personal/population/{year}"

personal_population_df = get_incidents(endpoint, personal_field, format_type)
personal_population_df = translate_df(personal_population_df, bjsPersonalDataSetFields_df, 2)
personal_population_df

# %% [markdown]
# # HOUSEHOLD victimization datasets

# %% [markdown]
# ## Description of the FIELDS or columns used in the HOUSEHOLD victimization datasets

# %%
# ENDPOINT
endpoint = "/bjs/ncvs/v2/household/fields/"

bjsHouseholdDataSetFields_df = get_fields(endpoint)
bjsHouseholdDataSetFields_df

# %% [markdown]
# ## HOUSEHOLD victimization COUNTS of incidents reported to the NCVS by year 2019

# %%
# ENDPOINT
endpoint = f"/bjs/ncvs/v2/household/{year}"

household_counts_df = get_incidents(endpoint, household_field, format_type)
household_counts_df = translate_df(household_counts_df, bjsHouseholdDataSetFields_df, 2)
household_counts_df

# %% [markdown]
# ## HOUSEHOLD victimization POPULATION of incidents reported to the NCVS by year 2019

# %%
# ENDPOINT
endpoint = f"/bjs/ncvs/v2/household/population/{year}"

household_population_df = get_incidents(endpoint, household_field, format_type)
household_population_df = translate_df(household_population_df, bjsHouseholdDataSetFields_df, 2)

# %% [markdown]
# ## Plotting the Data

# %% [markdown]
# ### x_values vs. y_values Plot

# %%
# build_scatter_plot(df, colx, coly, title, xlabel, ylabel, file)

# %% [markdown]
# ## Linear Regression

# %%
# build_linear_regression(df, colx, coly, title, xlabel, ylabel, file, le_x, le_y, r_x, r_y)
